# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("/content/drive/MyDrive/archive (2).zip")
data
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
data.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...

# %%
data.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
data.shape
# Out:
# (1048575, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
data.PREGNANT=data.PREGNANT.replace(97,2)
data
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
data.PREGNANT=data.PREGNANT.replace(99,2)

# %%
data.INTUBED=data.INTUBED.replace(99,2)
data
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
data.INTUBED=data.INTUBED.replace(97,2)
data
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020        2
# 1            2             1    2             1  03/06/2020        2
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020        2
# 4            2             1    2             1  21/06/2020        2
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99        2
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99        2
# 1048573      2            13    2             1  9999-99-99        2
# 1048574      2            13    2             1  9999-99-99        2
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
data.ICU=data.ICU.replace(97,2)

# %%
data.ICU=data.ICU.replace(99,2)

# %%
data
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020        2
# 1            2             1    2             1  03/06/2020        2
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020        2
# 4            2             1    2             1  21/06/2020        2
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99        2
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99        2
# 1048573      2            13    2             1  9999-99-99        2
# 1048574      2            13    2             1  9999-99-99        2
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
data.dtypes
# Out:
# USMER                    int64
# MEDICAL_UNIT             int64
# SEX                      int64
# PATIENT_TYPE             int64
# DATE_DIED               object
# INTUBED                  int64
# PNEUMONIA                int64
# AGE                      int64
# PREGNANT                 int64
# DIABETES                 int64
# COPD                     int64
# ASTHMA                   int64
# INMSUPR                  int64
# HIPERTENSION             int64
# OTHER_DISEASE            int64
# CARDIOVASCULAR           int64
# OBESITY                  int64
# RENAL_CHRONIC            int64
# TOBACCO                  int64
# CLASIFFICATION_FINAL     int64
# ICU                      int64
# dtype: object

# %%
data["DEATH"]=[2 if each=="9999-99-99" else 1 for each in data.DATE_DIED]
data
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020        2
# 1            2             1    2             1  03/06/2020        2
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020        2
# 4            2             1    2             1  21/06/2020        2
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99        2
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99        2
# 1048573      2            13    2             1  9999-99-99        2
# 1048574      2            13    2             1  9999-99-99        2
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# ...

# %%
data1=data.drop(["DATE_DIED"],axis=1)
data1.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'INTUBED', 'PNEUMONIA',
#        'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU', 'DEATH'],
#       dtype='object')

# %%
data.describe()
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  1.967903e+00
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  1.762575e-01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  2.000000e+00
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  2.000000e+00
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  2.000000e+00
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  2.000000e+00
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  2.335935e+00  2.186404e+00  2.260569e+00
# ...

# %%
dgraph=data.select_dtypes(include=["int64"])
dgraph.hist(figsize=(25,15))
plt.show()

# %%
corrmatrix=data.corr()
plt.subplots(figsize=(20,15))
sns.heatmap(corrmatrix,vmin=0.7,vmax=0.9,annot=True,linewidths=0.2,cmap="YlOrRd")

# %%
y=data1["DEATH"]
x=data1.drop(["DEATH"],axis=1)

# %%
data1
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  \
# 0            2             1    1             1        2          1   65
# 1            2             1    2             1        2          1   72
# 2            2             1    2             2        1          2   55
# 3            2             1    1             1        2          2   53
# 4            2             1    2             1        2          2   68
# ...        ...           ...  ...           ...      ...        ...  ...
# 1048570      2            13    2             1        2          2   40
# 1048571      1            13    2             2        2          2   51
# 1048572      2            13    2             1        2          2   55
# 1048573      2            13    2             1        2          2   28
# 1048574      2            13    2             1        2          2   52
#
#          PREGNANT  DIABETES  COPD  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.25)

# %%
from sklearn import linear_model
lr=linear_model.LinearRegression()

# %%
model=lr.fit(x_train,y_train)

# %%
predictions=model.predict(x_test)

# %%
print(predictions)
# Out:
# [2.03047925 2.03223338 2.09474136 ... 1.87368448 1.25388338 2.00295584]

# %%
from sklearn.metrics import mean_squared_error
print("MSE:",mean_squared_error(y_test,predictions))
# Out:
# MSE: 0.040241954235979725

# %%
from sklearn.metrics import r2_score
print("R2_score is:",r2_score(y_test,predictions))
# Out:
# R2_score is: 0.40179936861642795
